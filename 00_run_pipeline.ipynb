# %%
import yaml

with open("../config/config.yaml", "r") as file:
    config = yaml.safe_load(file)

print("✅ Config Loaded Successfully")

print(config)
# Out:
# ✅ Config Loaded Successfully
# {'paths': {'raw_data': 'data/raw', 'processed_data': 'data/processed', 'archive_data': 'data/archive', 'logs': 'logs'}, 'cleaning': {'drop_duplicates': True, 'fill_missing': {'CustomerID': 0}, 'remove_negative_values': ['Quantity', 'UnitPrice']}, 'outliers': {'columns': ['Quantity', 'UnitPrice'], 'iqr_multiplier': 1.5}}

# %%
import sys
import os

# Move to project root
os.chdir("..")

# Add project to path
sys.path.append(os.getcwd())

from src.data_loader import get_latest_file, load_data

raw_path = "data/raw"

file = get_latest_file(raw_path)

df = load_data(file)

df.head()
# Out:
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
import sys
import os

# Move to project root
os.chdir("..")

# Add project path
sys.path.append(os.getcwd())

from src.utils.helpers import create_timestamp

# Test timestamp
ts = create_timestamp()

print("Timestamp:", ts)
# Out:
# 🕒 Timestamp created: 20260421_183014
# Timestamp: 20260421_183014

# %%
import sys
import os

# Move to project root
os.chdir("..")

# Add project path
sys.path.append(os.getcwd())

from src.utils.logger import setup_logger

# Setup logger
logger = setup_logger("logs")

logger.info("Test log message")

print("Logger test completed")
# Out:
# 📝 Logger setup complete
# Logger test completed

# %%
import sys
import os

# Move to project root
os.chdir("..")

# Add project path
sys.path.append(os.getcwd())

from src.pipeline import run_pipeline

# Run full pipeline
run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# 📝 Logger setup complete
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 5268
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 10587
# 🚫 Negative values removed from UnitPrice: 2
# ✅ Data cleaning completed
# 📊 Starting outlier detection...
# 🔍 Processing column: Quantity
# 🚫 Outliers removed from Quantity: 27355
# 🔍 Processing column: UnitPrice
# 🚫 Outliers removed from UnitPrice: 37516
# ✅ Outlier detection completed
# 🕒 Timestamp created: 20260422_160744
# 💾 Cleaned file saved: data/processed/cleaned_data_20260422_160744.csv
# 📦 File moved to archive: data/archive/Retail .csv
# ✅ Pipeline Completed Successfully

# %%
import sys
import os

os.chdir("..")

sys.path.append(os.getcwd())

from src.pipeline import run_pipeline

run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 sys.path.append(os.getcwd())
#       8 from src.pipeline import run_pipeline
# ---> 10 run_pipeline()
#
# File ~/Outlier-Analysis-Automation/src/pipeline.py:29, in run_pipeline()
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/config.yaml'

# %%
import sys
import os

os.chdir("..")

sys.path.append(os.getcwd())

from src.pipeline import run_pipeline

run_pipeline()

# %%
import os

print("Current Directory:", os.getcwd())

print("\nFiles inside data/raw:")

print(os.listdir("data/raw"))
# Out:
# Current Directory: /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation/notebooks
#
# Files inside data/raw:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       3 print("Current Directory:", os.getcwd())
#       5 print("\nFiles inside data/raw:")
# ----> 7 print(os.listdir("data/raw"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw'

# %%
import os
import sys

# Move directly to your project folder
os.chdir("/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation")

# Add project to Python path
sys.path.append(os.getcwd())

print("✅ Now inside project folder:")
print(os.getcwd())

print("\n📂 Files inside data/raw:")

print(os.listdir("data/raw"))
# Out:
# ✅ Now inside project folder:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation
#
# 📂 Files inside data/raw:
# ['.ipynb_checkpoints', 'Retail .csv']

# %%
from src.pipeline import run_pipeline

run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# 📝 Logger setup complete
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 5268
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 10587
# 🚫 Negative values removed from UnitPrice: 2
# ✅ Data cleaning completed
# 📊 Starting outlier detection...
# 🔍 Processing column: Quantity
# 🚫 Outliers removed from Quantity: 27355
# 🔍 Processing column: UnitPrice
# 🚫 Outliers removed from UnitPrice: 37516
# ✅ Outlier detection completed
# 📊 Generating charts...
# 📦 Quantity boxplot saved
# 📊 UnitPrice histogram saved
# ✅ Charts generated successfully
# 🕒 Timestamp created: 20260422_164105
# 💾 Cleaned file saved: data/processed/cleaned_data_20260422_164105.csv
# 📦 File moved to archive: data/archive/Retail .csv
# ✅ Pipeline Completed Successfully

# %%
import os
import sys

# Move to project root
os.chdir("/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation")

# Add project path
sys.path.append(os.getcwd())

print("✅ Working Directory:")
print(os.getcwd())

print("\n📂 Project Files:")
print(os.listdir())
# Out:
# ✅ Working Directory:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation
#
# 📂 Project Files:
# ['run_pipeline.py', '.ipynb_checkpoints', 'notebooks', 'models', 'data', 'requirements.txt', 'src', 'README.md', 'logs', 'config', 'outputs', 'powerbi']

# %%
import os
import sys

project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

os.chdir(project_path)

sys.path.append(project_path)

print("✅ Working Directory:")
print(os.getcwd())
# Out:
# ✅ Working Directory:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation

# %%
from src.pipeline import run_pipeline

run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# Loaded paths: {'raw_data': 'data/raw', 'processed_data': 'data/processed', 'archive_data': 'data/archive', 'charts': 'outputs/charts', 'reports': 'outputs/reports', 'logs': 'logs'}
# 📝 Logger setup complete
# 🕒 Timestamp created: 20260423_183708
# 📂 Checking raw folder...
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
# 📊 Data Shape: (541909, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 5268
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 10587
# 🚫 Negative values removed from UnitPrice: 2
# ✅ Data cleaning completed
# After Cleaning: (526052, 8)
# 📊 Starting outlier detection...
# 🔍 Processing column: Quantity
# 🚫 Outliers removed from Quantity: 27355
# 🔍 Processing column: UnitPrice
# 🚫 Outliers removed from UnitPrice: 37516
# ...

# %%
import os
import sys

# Set project path
project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

# Move to project root
os.chdir(project_path)

# Add project to Python path
if project_path not in sys.path:
    sys.path.append(project_path)

print("✅ Working Directory:")
print(os.getcwd())

print("\n📂 Available Folders:")
print(os.listdir())
# Out:
# ✅ Working Directory:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation
#
# 📂 Available Folders:
# ['run_pipeline.py', '.ipynb_checkpoints', 'notebooks', 'models', 'data', 'requirements.txt', 'src', 'README.md', 'logs', 'config', 'outputs', 'powerbi']

# %%
from src.pipeline import run_pipeline

run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# Loaded paths: {'raw_data': 'data/raw', 'processed_data': 'data/processed', 'archive_data': 'data/archive', 'charts': 'outputs/charts', 'reports': 'outputs/reports', 'logs': 'logs'}
# 📝 Logger setup complete
# 🕒 Timestamp created: 20260423_184446
# 📂 Checking raw folder...
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
# 📊 Data Shape: (541909, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 5268
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 10587
# 🚫 Negative values removed from UnitPrice: 2
# ✅ Data cleaning completed
# After Cleaning: (526052, 8)
# 📊 Starting outlier detection...
# 🔍 Processing column: Quantity
# 🚫 Outliers removed from Quantity: 27355
# 🔍 Processing column: UnitPrice
# 🚫 Outliers removed from UnitPrice: 37516
# ✅ Outlier detection completed
# ...

# %%
import os
import sys

# Set project path
project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

# Move to project root
os.chdir(project_path)

# Add project to Python path
if project_path not in sys.path:
    sys.path.append(project_path)

print("✅ Working Directory:")
print(os.getcwd())

print("\n📂 Project Folders:")
print(os.listdir())
# Out:
# ✅ Working Directory:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation
#
# 📂 Project Folders:
# ['run_pipeline.py', '.ipynb_checkpoints', 'notebooks', 'models', 'data', 'requirements.txt', 'src', 'README.md', 'logs', 'config', 'outputs', 'powerbi']

# %%
import os
import sys

project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

os.chdir(project_path)

if project_path not in sys.path:
    sys.path.append(project_path)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation

# %%
from src.pipeline import run_pipeline

run_pipeline()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.pipeline import run_pipeline
#       3 run_pipeline()
#
# ImportError: cannot import name 'run_pipeline' from 'src.pipeline' (/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation/src/pipeline.py)

# %%
import os
import sys
import importlib

project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

os.chdir(project_path)

if project_path not in sys.path:
    sys.path.append(project_path)

# Force reload module
import src.pipeline
importlib.reload(src.pipeline)

from src.pipeline import run_pipeline

print("✅ run_pipeline imported successfully")
# Out:
# ✅ run_pipeline imported successfully

# %%
run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# Loaded paths: {'raw_data': 'data/raw', 'processed_data': 'data/processed', 'archive_data': 'data/archive', 'charts': 'outputs/charts', 'reports': 'outputs/reports', 'logs': 'logs'}
# 📝 Logger setup complete
# 🕒 Timestamp created: 20260423_190154
# 📂 Checking raw folder...
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (541909, 8)
# 📊 Data Shape: (541909, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 5268
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 10587
# 🚫 Negative values removed from UnitPrice: 2
# ✅ Data cleaning completed
# After Cleaning: (526052, 8)
# 📊 Starting outlier detection...
# 🔍 Processing column: Quantity
# 🚫 Outliers removed from Quantity: 27355
# 🔍 Processing column: UnitPrice
# 🚫 Outliers removed from UnitPrice: 37516
# ✅ Outlier detection completed
# ...

# %%
import os
import sys

project_path = "/home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation"

os.chdir(project_path)

if project_path not in sys.path:
    sys.path.append(project_path)

from src.pipeline import run_pipeline

run_pipeline()
# Out:
# 🚀 Starting Pipeline...
# Loaded paths: {'raw_data': 'data/raw', 'processed_data': 'data/processed', 'archive_data': 'data/archive', 'charts': 'outputs/charts', 'reports': 'outputs/reports', 'logs': 'logs'}
# 🧹 Old files removed from data/processed
# 🧹 Old files removed from outputs/charts
# 🧹 Old files removed from outputs/reports
# 🧹 Old files removed from logs
# 📝 Logger setup complete
# 🕒 Timestamp created: 20260424_051639
# 📂 Checking raw folder...
# 📂 Checking raw folder...
# ✅ Latest file detected: data/raw/Retail .csv
# ✅ Latest file detected: data/raw/Retail .csv
# 📥 Loading file...
# ✅ File loaded successfully
# 📊 Data Shape: (247210, 8)
# 📊 Data Shape: (247210, 8)
# 🧹 Starting data cleaning...
# 🧾 Duplicates removed: 2040
# 🧩 Missing values filled in CustomerID
# 🚫 Negative values removed from Quantity: 5283
# 🚫 Negative values removed from UnitPrice: 0
# ✅ Data cleaning completed
# After Cleaning: (239887, 8)
# 📊 Starting outlier detection...
# ...

# %%
# Create .gitignore file using Python

content = """
# Python cache
__pycache__/
*.pyc
*.pyo

# Jupyter checkpoints
.ipynb_checkpoints/

# Logs
logs/
*.log

# Processed data
data/processed/
data/archive/

# Output charts & reports
outputs/charts/
outputs/reports/

# System files
.DS_Store
Thumbs.db

# Virtual environments
venv/
env/
.venv/

# IDE settings
.vscode/
.idea/
"""

with open(".gitignore", "w") as f:
    f.write(content)

print(".gitignore file created successfully!")
# Out:
# .gitignore file created successfully!

# %%
import os

print(os.getcwd())
# Out:
# /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation/notebooks

# %%
import os

# Go to main project folder
project_root = os.path.abspath("..")

# .gitignore content
content = """
# Python cache
__pycache__/
*.pyc
*.pyo

# Jupyter checkpoints
.ipynb_checkpoints/

# Logs
logs/
*.log

# Processed data
data/processed/
data/archive/

# Output charts & reports
outputs/charts/
outputs/reports/

# System files
.DS_Store
Thumbs.db

# Virtual environments
venv/
env/
.venv/

# IDE settings
.vscode/
.idea/
"""

# Create .gitignore in project root
file_path = os.path.join(project_root, ".gitignore")

with open(file_path, "w") as f:
    f.write(content)

print(".gitignore created at:", file_path)
# Out:
# .gitignore created at: /home/01eab4af-7164-4655-a9f6-3e3143c902ae/Outlier-Analysis-Automation/.gitignore

# %%
import os

project_root = os.path.abspath("..")

print("Files in project root:\n")

for f in os.listdir(project_root):
    print(f)
# Out:
# Files in project root:
#
# .gitignore
# run_pipeline.py
# .ipynb_checkpoints
# notebooks
# models
# data
# requirements.txt
# src
# README.md
# logs
# config
# outputs
# powerbi
